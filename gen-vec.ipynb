# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime
import pathlib

# %%
df = pd.read_csv('result.csv')
output_path = pathlib.Path('vec')
def point_format(lat, lon):
    return f'TYPE = POINT  COLOR = 10  WIDTH = 5 GEO = ({lat:0.4f}, {lon:0.4f})'
mask = df['relative_depth'] >= 400
